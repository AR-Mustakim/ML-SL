# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk

# %% [markdown]
# # load data

# %%
dfKG = pd.read_csv('tweets_data/1_KG_4-26.csv')
dfKN = pd.read_csv('tweets_data/3_KN_4-29.csv')
dfSH = pd.read_csv('tweets_data/4_SH_4-29.csv')
dfCM = pd.read_csv('tweets_data/5_CM_4-29.csv')
dfJG = pd.read_csv('tweets_data/7_JG_4-29.csv')
dfUPSR = pd.read_csv('tweets_data/8_UPSR_5-5.csv')
dfARN = pd.read_csv('tweets_data/9_ARN_5-5.csv')

# %% [markdown]
# # Viewing dataset

# %%
dfKG.head(5)
# Out:
#                                                  Raw  \
# 0  Time raya juak sik blh merentas 😀😀 tpi bazaar ...
# 1  @501Awani Guna saluran yang betul is not valid...
# 2  Kan dah kata, lelaki Melayu Isle Konservatif t...
# 3  @501Awani Kenapa tak ajak rakyat join sekali b...
# 4  #CoronavirusIndia #FlipFlop #flipped #sports #...
#
#                                            CD-Malaya  \
# 0  masa raya juak sik boleh merentas tapi bazar b...
# 1  <user> guna saluran yang betul tidak sah lagi....
# 2  kan dah kata, melayu lelaki konservatif pulau ...
# 3  <user> kenapa tidak ajak rakyat berbuka? kan k...
# 4  <hashtag>coronavirusindia</hashtag> <hashtag>f...
#
#                                                CD-RE
# 0  time raya juak sik blh merentas tpi bazaar blh...
# 1   guna saluran yang betul is not valid anymore ...
# 2  kan dah kata lelaki melayu isle konservatif ta...
# 3   kenapa tak ajak rakyat join sekali berbuka ka...
# 4                                                NaN

# %%
dfKG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Raw        100 non-null    object
#  1   CD-Malaya  100 non-null    object
#  2   CD-RE      89 non-null     object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
dfKN.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Raw        100 non-null    object
#  1   CD-Malaya  100 non-null    object
#  2   CD-RE      100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# ## DFKG

# %%
stop_words = ["t", "nan", "s","di","the","this","i","in","of","or","is","if","it","at",'hashtag','ke','co','yang','u','https']

# %%
#visualize Word cloud - plotting
plt.figure(figsize = (20,10))
allWords =' '.join([twts for twts in dfKG['Raw']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110, max_words=70,  stopwords = stop_words).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
plt.figure(figsize = (20,10))
allWords =' '.join([str(twts) for twts in dfKG['CD-RE']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110, stopwords=stop_words, max_words=70).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## DFKN

# %%
#visualize Word cloud - plotting
plt.figure(figsize = (20,10))
stopper =['shopee','tokopedia','bukalapak','link','klik link','ready stock','and','ready','stock',"klik",'bio ya','bio', 'on','di bio']
allWords =' '.join([twts for twts in dfKN['CD-RE']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110, stopwords=stopper,max_words=70).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# *since Raw data contains mostly link, while CD-Malaya contain mostly annotation (<hashtag>,<link> and etc), so from now on, I decide to do EDA just for CD-RE dataset*
# ## DFSH

# %%
#visualize Word cloud - plotting
plt.figure(figsize = (20,10))
allWords =' '.join([twts for twts in dfSH['CD-RE']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110,max_words=70, stopwords=stop_words).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## DFCM

# %%
#visualize Word cloud - plotting
plt.figure(figsize = (20,10))
allWords =' '.join([twts for twts in dfCM['CD-RE']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## DHJG

# %%
dfJG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Raw        100 non-null    object
#  1   CD-Malaya  100 non-null    object
#  2   CD-RE      83 non-null     object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
#visualize Word cloud - plotting
plt.figure(figsize = (20,10))
allWords =' '.join([str(twts) for twts in dfJG['CD-RE']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110, stopwords=stop_words, max_words=50).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## DFUPSR

# %%
plt.figure(figsize = (20,10))
allWords =' '.join([str(twts) for twts in dfUPSR['CD-RE']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110, stopwords=stop_words, max_words=50).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## DFARN

# %%
plt.figure(figsize = (20,10))
allWords =' '.join([str(twts) for twts in dfARN['CD-RE']])
wordCloud = WordCloud(width = 900, height=700, random_state =21, max_font_size=110, stopwords=stop_words, max_words=50).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()
